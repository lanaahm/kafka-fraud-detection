# %%
import pandas as pd
import json
from kafka import KafkaConsumer

consumer = KafkaConsumer("project_4", bootstrap_servers='localhost')
print("Starting the consumer")

all_data = pd.DataFrame()

for msg in consumer:
    print(f"Records = {json.loads(msg.value)}")
    
    data = json.loads(msg.value)
    
    all_data = all_data.append(pd.DataFrame([data]), ignore_index=True)

print(all_data)
# Out:
# Starting the consumer
# Records = {'step': 1, 'type': 'PAYMENT', 'amount': 9839.64, 'nameOrig': 'C1231006815', 'newbalanceOrig': 160296.36, 'nameDest': 'M1979787155', 'newbalanceDest': 0.0}
# Records = {'step': 1, 'type': 'PAYMENT', 'amount': 1864.28, 'nameOrig': 'C1666544295', 'newbalanceOrig': 19384.72, 'nameDest': 'M2044282225', 'newbalanceDest': 0.0}
# Records = {'step': 1, 'type': 'TRANSFER', 'amount': 181.0, 'nameOrig': 'C1305486145', 'newbalanceOrig': 0.0, 'nameDest': 'C553264065', 'newbalanceDest': 0.0}
# Records = {'step': 1, 'type': 'CASH_OUT', 'amount': 181.0, 'nameOrig': 'C840083671', 'newbalanceOrig': 0.0, 'nameDest': 'C38997010', 'newbalanceDest': 0.0}
# Records = {'step': 1, 'type': 'PAYMENT', 'amount': 11668.14, 'nameOrig': 'C2048537720', 'newbalanceOrig': 29885.86, 'nameDest': 'M1230701703', 'newbalanceDest': 0.0}
# ...

# %%
all_data
# Out:
#     step      type     amount     nameOrig  newbalanceOrig     nameDest  \
# 0      1   PAYMENT    9839.64  C1231006815       160296.36  M1979787155
# 1      1   PAYMENT    1864.28  C1666544295        19384.72  M2044282225
# 2      1  TRANSFER     181.00  C1305486145            0.00   C553264065
# 3      1  CASH_OUT     181.00   C840083671            0.00    C38997010
# 4      1   PAYMENT   11668.14  C2048537720        29885.86  M1230701703
# 5      1   PAYMENT    7817.71    C90045638        46042.29   M573487274
# 6      1   PAYMENT    7107.77   C154988899       176087.23   M408069119
# 7      1   PAYMENT    7861.64  C1912850431       168225.59   M633326333
# 8      1   PAYMENT    4024.36  C1265012928            0.00  M1176932104
# 9      1     DEBIT    5337.77   C712410124        36382.23   C195600860
# 10     1     DEBIT    9644.94  C1900366749            0.00   C997608398
# 11     1   PAYMENT    3099.97   C249177573        17671.03  M2096539129
# ...

# %%
producer = all_data
producer
# Out:
#     step      type     amount     nameOrig  newbalanceOrig     nameDest  \
# 0      1   PAYMENT    9839.64  C1231006815       160296.36  M1979787155
# 1      1   PAYMENT    1864.28  C1666544295        19384.72  M2044282225
# 2      1  TRANSFER     181.00  C1305486145            0.00   C553264065
# 3      1  CASH_OUT     181.00   C840083671            0.00    C38997010
# 4      1   PAYMENT   11668.14  C2048537720        29885.86  M1230701703
# 5      1   PAYMENT    7817.71    C90045638        46042.29   M573487274
# 6      1   PAYMENT    7107.77   C154988899       176087.23   M408069119
# 7      1   PAYMENT    7861.64  C1912850431       168225.59   M633326333
# 8      1   PAYMENT    4024.36  C1265012928            0.00  M1176932104
# 9      1     DEBIT    5337.77   C712410124        36382.23   C195600860
# 10     1     DEBIT    9644.94  C1900366749            0.00   C997608398
# 11     1   PAYMENT    3099.97   C249177573        17671.03  M2096539129
# ...

# %%
from sqlalchemy import create_engine
import pandas as pd

dbname="project_4"
user="postgres"
password="postgres"
host="localhost"
port="5432"

# URL koneksi ke PostgreSQL
db_url = f"postgresql://{user}:{password}@{host}:{port}/{dbname}"
engine = create_engine(db_url)
df = pd.read_sql_query('SELECT * FROM old_information',engine)

# %%
df
# Out:
#           nameOrig  oldbalanceOrg     nameDest  oldbalanceDest
# 0      C1231006815       170136.0  M1979787155            0.00
# 1      C1666544295        21249.0  M2044282225            0.00
# 2      C1305486145          181.0   C553264065            0.00
# 3       C840083671          181.0    C38997010        21182.00
# 4      C2048537720        41554.0  M1230701703            0.00
# ...            ...            ...          ...             ...
# 14995  C1467327074        29051.0   C191614132         9701.14
# 14996   C932879787            0.0   M902010316            0.00
# 14997  C1430251794            0.0   M799225701            0.00
# 14998  C1287098623        55498.0  M1702039888            0.00
# 14999  C1336808341       184122.0  C1336996537       444596.14
#
# [15000 rows x 4 columns]

# %%
data = producer.merge(df, how='inner', on=['nameOrig','nameDest'])
predict = data.drop(['nameOrig','nameDest'], axis=1)
predict
# Out:
#     step      type     amount  newbalanceOrig  newbalanceDest  oldbalanceOrg  \
# 0      1   PAYMENT    9839.64       160296.36            0.00      170136.00
# 1      1   PAYMENT    1864.28        19384.72            0.00       21249.00
# 2      1  TRANSFER     181.00            0.00            0.00         181.00
# 3      1  CASH_OUT     181.00            0.00            0.00         181.00
# 4      1   PAYMENT   11668.14        29885.86            0.00       41554.00
# 5      1   PAYMENT    7817.71        46042.29            0.00       53860.00
# 6      1   PAYMENT    7107.77       176087.23            0.00      183195.00
# 7      1   PAYMENT    7861.64       168225.59            0.00      176087.23
# 8      1   PAYMENT    4024.36            0.00            0.00        2671.00
# 9      1     DEBIT    5337.77        36382.23        40348.79       41720.00
# 10     1     DEBIT    9644.94            0.00       157982.12        4465.00
# ...

# %%
data = producer.merge(df, how='inner', on=['nameOrig', 'nameDest'])
predict_df = data.drop(['nameOrig', 'nameDest'], axis=1)
predict_dict = predict_df.to_dict('index')

# %%
import os
import pandas as pd
from modelling import FraudModel

def run_fraud_models(predict_dict, model_path):
    results = []
    for index, predict in predict_dict.items():
        try:
            result = FraudModel.runModel(predict, model_path)
            results.append(result)
        except KeyError as e:
            print(f"KeyError for index {index}: {e}")
        except Exception as e:
            print(f"An error occurred for index {index}: {e}")
    return results

def main():
    path = os.path.join(os.getcwd(), "modelling")
    # Assuming predict_dict is defined somewhere in your code
    predict_dict = {
        
    }
    results = run_fraud_models(predict_dict, path)
    print(results)

if __name__ == "__main__":
    main()
# Out:
# []

# %%
from modelling import FraudModel
import os

path = os.getcwd()
path = path + "\\modelling\\"
result = FraudModel.runModel(predict, path)
# Out:
# C:\Users\MSI\anaconda3\lib\site-packages\sklearn\base.py:310: UserWarning: Trying to unpickle estimator OneHotEncoder from version 1.3.0 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# C:\Users\MSI\anaconda3\lib\site-packages\sklearn\base.py:310: UserWarning: Trying to unpickle estimator StandardScaler from version 1.3.0 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# C:\Users\MSI\anaconda3\lib\site-packages\sklearn\base.py:310: UserWarning: Trying to unpickle estimator StandardScaler from version 1.3.0 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# ...

# %%
result
# Out:
# 'White List'

# %%
data['predict'] = result
data
# Out:
#     step      type     amount     nameOrig  newbalanceOrig     nameDest  \
# 0      1   PAYMENT    9839.64  C1231006815       160296.36  M1979787155
# 1      1   PAYMENT    1864.28  C1666544295        19384.72  M2044282225
# 2      1  TRANSFER     181.00  C1305486145            0.00   C553264065
# 3      1  CASH_OUT     181.00   C840083671            0.00    C38997010
# 4      1   PAYMENT   11668.14  C2048537720        29885.86  M1230701703
# 5      1   PAYMENT    7817.71    C90045638        46042.29   M573487274
# 6      1   PAYMENT    7107.77   C154988899       176087.23   M408069119
# 7      1   PAYMENT    7861.64  C1912850431       168225.59   M633326333
# 8      1   PAYMENT    4024.36  C1265012928            0.00  M1176932104
# 9      1     DEBIT    5337.77   C712410124        36382.23   C195600860
# 10     1     DEBIT    9644.94  C1900366749            0.00   C997608398
# 11     1   PAYMENT    3099.97   C249177573        17671.03  M2096539129
# ...

# %%
from pymongo import MongoClient

# Mengatur koneksi ke MongoDB
# data = pd.read_csv("producer/")
username = "postgres" 
password = "postgres" 
# Replace these with your connection details
client_uri = f"mongodb://{username}:{password}@localhost:5432/test_db?authSource=admin" 
mongo_client = MongoClient(client_uri) 

db = mongo_client["project_4"]
collection = db["project_4-collection"]
data_dicts = data.to_dict('records')  


if isinstance(data_dicts, list) and data_dicts:
    collection.insert_many(data_dicts)
    print("All data has been saved to MongoDB")
else:
    print("No data to save")
# Out:
# All data has been saved to MongoDB

# %%
# Membaca data dari MongoDB ke dalam list of dictionaries
data_from_mongo = list(collection.find())
    
# Membaca data ke dalam DataFrame
df = pd.DataFrame(data_from_mongo)
df
# Out:
#                          _id  step      type     amount     nameOrig  \
# 0   6690e204bde8308fcb424226     1   PAYMENT   11668.14  C2048537720
# 1   6690e3a8bde8308fcb424228     1   PAYMENT   11668.14  C2048537720
# 2   6690ed2834d1f1cfa18055f0     1   PAYMENT    9839.64  C1231006815
# 3   6690ed2834d1f1cfa18055f1     1   PAYMENT    1864.28  C1666544295
# 4   6690ed2834d1f1cfa18055f2     1  TRANSFER     181.00  C1305486145
# 5   6690ed2834d1f1cfa18055f3     1  CASH_OUT     181.00   C840083671
# 6   6690ed2834d1f1cfa18055f4     1   PAYMENT   11668.14  C2048537720
# 7   6690ed2834d1f1cfa18055f5     1   PAYMENT    7817.71    C90045638
# 8   6690ed2834d1f1cfa18055f6     1   PAYMENT    7107.77   C154988899
# 9   6690ed2834d1f1cfa18055f7     1   PAYMENT    7861.64  C1912850431
# 10  6690ed2834d1f1cfa18055f8     1   PAYMENT    4024.36  C1265012928
# 11  6690ed2834d1f1cfa18055f9     1     DEBIT    5337.77   C712410124
# 12  6690ed2834d1f1cfa18055fa     1     DEBIT    9644.94  C1900366749
# ...

# %%
data_from_mongo = list(collection.find())

# Load data into a DataFrame
df = pd.DataFrame(data_from_mongo)

# Display the DataFrame before dropping rows
print("DataFrame before dropping rows with NaN in 'predict':")
print(df)

# Drop rows where 'predict' column is NaN
df_cleaned = df.dropna(subset=['predict'])

# Display the DataFrame after dropping rows
print("DataFrame after dropping rows with NaN in 'predict':")
print(df_cleaned)

# Get the IDs of the documents to be removed
ids_to_remove = df[df['predict'].isna()]['_id'].tolist()

# Remove the corresponding documents from MongoDB
result = collection.delete_many({'_id': {'$in': ids_to_remove}})
print(f"Deleted {result.deleted_count} documents with NaN in 'predict' column.")
# Out:
# DataFrame before dropping rows with NaN in 'predict':
#                          _id  step      type     amount     nameOrig  \
# 0   6690e3a8bde8308fcb424228     1   PAYMENT   11668.14  C2048537720
# 1   6690ed7234d1f1cfa1805605     1   PAYMENT    9839.64  C1231006815
# 2   6690ed7234d1f1cfa1805606     1   PAYMENT    1864.28  C1666544295
# 3   6690ed7234d1f1cfa1805607     1  TRANSFER     181.00  C1305486145
# 4   6690ed7234d1f1cfa1805608     1  CASH_OUT     181.00   C840083671
# 5   6690ed7234d1f1cfa1805609     1   PAYMENT   11668.14  C2048537720
# 6   6690ed7234d1f1cfa180560a     1   PAYMENT    7817.71    C90045638
# 7   6690ed7234d1f1cfa180560b     1   PAYMENT    7107.77   C154988899
# 8   6690ed7234d1f1cfa180560c     1   PAYMENT    7861.64  C1912850431
# 9   6690ed7234d1f1cfa180560d     1   PAYMENT    4024.36  C1265012928
# 10  6690ed7234d1f1cfa180560e     1     DEBIT    5337.77   C712410124
# 11  6690ed7234d1f1cfa180560f     1     DEBIT    9644.94  C1900366749
# ...

# %%
# Membaca data dari MongoDB ke dalam list of dictionaries
data_from_mongo = list(collection.find())
    
# Membaca data ke dalam DataFrame
df = pd.DataFrame(data_from_mongo)
df
# Out:
#                          _id  step      type     amount     nameOrig  \
# 0   6690e3a8bde8308fcb424228     1   PAYMENT   11668.14  C2048537720
# 1   6690ed7234d1f1cfa1805605     1   PAYMENT    9839.64  C1231006815
# 2   6690ed7234d1f1cfa1805606     1   PAYMENT    1864.28  C1666544295
# 3   6690ed7234d1f1cfa1805607     1  TRANSFER     181.00  C1305486145
# 4   6690ed7234d1f1cfa1805608     1  CASH_OUT     181.00   C840083671
# 5   6690ed7234d1f1cfa1805609     1   PAYMENT   11668.14  C2048537720
# 6   6690ed7234d1f1cfa180560a     1   PAYMENT    7817.71    C90045638
# 7   6690ed7234d1f1cfa180560b     1   PAYMENT    7107.77   C154988899
# 8   6690ed7234d1f1cfa180560c     1   PAYMENT    7861.64  C1912850431
# 9   6690ed7234d1f1cfa180560d     1   PAYMENT    4024.36  C1265012928
# 10  6690ed7234d1f1cfa180560e     1     DEBIT    5337.77   C712410124
# 11  6690ed7234d1f1cfa180560f     1     DEBIT    9644.94  C1900366749
# 12  6690ed7234d1f1cfa1805610     1   PAYMENT    3099.97   C249177573
# ...

# %%
df.to_csv('dataset.csv', index=False)
